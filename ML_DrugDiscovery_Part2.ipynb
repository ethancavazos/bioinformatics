# %% [markdown]
# <a href="https://colab.research.google.com/github/ethancavazos/bioinformatics/blob/main/ML_DrugDiscovery_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# ! pip install -U scikit-learn

# %%
# ! pip install lazypredict

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
# import io
# df = pd.read_csv(io.BytesIO(uploaded['acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv']))

# %%
df
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880  pIC50
# 0              1           1           1  ...             0             0   6.12
# 1              1           1           1  ...             0             0   7.00
# 2              1           1           1  ...             0             0   4.30
# 3              1           1           0  ...             0             0   6.52
# 4              1           1           0  ...             0             0   6.10
# ...          ...         ...         ...  ...           ...           ...    ...
# 4690           1           1           1  ...             0             0   5.60
# 4691           1           1           1  ...             0             0   5.42
# 4692           1           1           1  ...             0             0   5.46
# 4693           1           1           1  ...             0             0   5.56
# 4694           1           1           1  ...             0             0   6.33
#
# ...

# %%
X = df.drop('pIC50', axis=1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 4690           1           1  ...             0             0
# 4691           1           1  ...             0             0
# 4692           1           1  ...             0             0
# 4693           1           1  ...             0             0
# 4694           1           1  ...             0             0
#
# [4695 rows x 881 columns]

# %%
Y = df.pIC50
Y
# Out:
# 0      6.12
# 1      7.00
# 2      4.30
# 3      6.52
# 4      6.10
#        ...
# 4690   5.60
# 4691   5.42
# 4692   5.46
# 4693   5.56
# 4694   6.33
# Name: pIC50, Length: 4695, dtype: float64

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)

# %%
X.shape
# Out:
# (4695, 138)

# %%
Y.shape
# Out:
# (4695,)

# %%
X.shape
# Out:
# (4695, 138)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((3756, 138), (3756,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((939, 138), (939,))

# %%
import numpy as np
np.random.seed(100)
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.5190121816511254

# %%
Y_pred = model.predict(X_test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
X.shape
# Out:
# (4695, 138)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 138)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# ...
# 100%|██████████| 42/42 [00:00<00:00, 160877.41it/s]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                        Adjusted R-Squared  ...  Time Taken
# Model                                                      ...
# ExtraTreesRegressor                                  0.86  ...        6.13
# DecisionTreeRegressor                                0.86  ...        0.19
# ExtraTreeRegressor                                   0.86  ...        0.17
# GaussianProcessRegressor                             0.86  ...        5.01
# RandomForestRegressor                                0.83  ...        4.68
# XGBRegressor                                         0.83  ...        1.98
# BaggingRegressor                                     0.81  ...        0.59
# MLPRegressor                                         0.79  ...        7.17
# HistGradientBoostingRegressor                        0.68  ...        2.32
# LGBMRegressor                                        0.68  ...        0.44
# KNeighborsRegressor                                  0.64  ...        2.99
# ...

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
# Empty DataFrame
# Columns: [Adjusted R-Squared, R-Squared, RMSE, Time Taken]
# Index: []

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
